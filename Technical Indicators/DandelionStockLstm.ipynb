# %%
import numpy as np
import pandas as pd
import yfinance as yf
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
#Linear Regression
# Dandelion Optimizer Implementation
class DandelionOptimizer:
    def __init__(self, objective_function, num_features, population_size=20, max_iterations=50):
        self.objective_function = objective_function
        self.num_features = num_features
        self.population_size = population_size
        self.max_iterations = max_iterations
    
    def optimize(self):
        best_solution = np.random.randint(0, 2, self.num_features)
        best_score = self.objective_function(best_solution)
        
        for _ in range(self.max_iterations):
            candidate = np.random.randint(0, 2, self.num_features)
            candidate_score = self.objective_function(candidate)
            
            if candidate_score < best_score:
                best_solution = candidate
                best_score = candidate_score
        
        print("Best Feature Selection Solution:", best_solution)
        return best_solution

def fitness_function(solution, X, y):
    selected_features = X[:, solution == 1]
    if selected_features.shape[1] == 0:
        return float("inf")
    from sklearn.linear_model import LinearRegression
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import mean_absolute_error
    
    X_train, X_test, y_train, y_test = train_test_split(selected_features, y, test_size=0.2, random_state=42)
    if X_train.shape[0] == 0:
        return float("inf")
    
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return mean_absolute_error(y_test, y_pred)

def dandelion_optimizer_optimize(X, y):
    optimizer = DandelionOptimizer(lambda sol: fitness_function(sol, X, y), num_features=X.shape[1])
    return optimizer.optimize()

# Step 1: Load Stock Data
def load_stock_data(file_path):
    try:
        df = pd.read_csv(file_path)
        df['Date'] = pd.to_datetime(df['Date'])
        df.set_index('Date', inplace=True)
        return df
    except Exception as e:
        print(f"Error loading data: {e}")
        return pd.DataFrame()

# Step 2: Feature Engineering
def create_features(df):
    if df.empty:
        raise ValueError("Stock data is empty. Cannot proceed.")
    df['SMA_10'] = df['Close'].rolling(window=10).mean()
    df['SMA_50'] = df['Close'].rolling(window=50).mean()
    df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()
    df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()
    df['Momentum'] = df['Close'].diff(5)
    df['Volatility'] = df['Close'].rolling(window=10).std()
    df.dropna(inplace=True)
    return df

# Step 3: Feature Selection using Dandelion Optimizer
def feature_selection(X, y):
    best_features = dandelion_optimizer_optimize(X, y)
    if np.sum(best_features) == 0:
        print("Warning: No features selected! Using all features.")
        return X  # Use all features if none are selected
    return X[:, best_features == 1]

# Step 4: Prepare Data for LSTM
def prepare_data(df):
    feature_cols = ['SMA_10', 'SMA_50', 'EMA_10', 'EMA_50', 'Momentum', 'Volatility']
    X = df[feature_cols].values
    y = df['Close'].values
    
    X_selected = feature_selection(X, y)
    
    scaler_X = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X_selected)
    scaler_y = MinMaxScaler()
    y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))
    
    train_size = int(0.8 * len(X))
    if train_size == 0:
        raise ValueError("Not enough data for training. Check stock data.")
    
    X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
    y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]
    
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
    
    return X_train, X_test, y_train, y_test, scaler_X, scaler_y

# Step 5: Build LSTM Model
def build_lstm_model(input_shape):
    model = Sequential([
        LSTM(50, return_sequences=True, input_shape=input_shape),
        Dropout(0.2),
        LSTM(50, return_sequences=False),
        Dropout(0.2),
        Dense(25, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse')
    return model

# Step 6: Train and Predict
def train_predict_lstm(X_train, X_test, y_train, y_test, scaler_y):
    model = build_lstm_model((X_train.shape[1], X_train.shape[2]))
    model.fit(X_train, y_train, epochs=500, batch_size=32, validation_data=(X_test, y_test), verbose=1)
    
    predictions = model.predict(X_test)
    predictions = scaler_y.inverse_transform(predictions)
    y_actual = scaler_y.inverse_transform(y_test)
    
    mse = mean_squared_error(y_actual, predictions)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_actual, predictions)
    r2 = r2_score(y_actual, predictions)
    
    print(f"MSE: {mse}, RMSE: {rmse}, MAE: {mae}, R2: {r2}")
    plt.figure(figsize=(12, 6))
    plt.plot(y_actual, label='Actual Price', color='blue')
    plt.plot(predictions, label='Predicted Price', color='red')
    plt.xlabel('Time')
    plt.ylabel('Stock Price')
    plt.title('Actual vs Predicted Stock Prices')
    plt.legend()
    # Save the figure
    plt.savefig('figLi5.png', dpi=300, bbox_inches='tight')
    plt.show()
    return model, predictions

# Main Execution
if __name__ == "__main__":
    file_path = 'NSE-TATAGLOBAL.csv'
    df = load_stock_data(file_path)
    if df.empty:
        raise ValueError("Stock data retrieval failed. Exiting.")
    
    df = create_features(df)
    X_train, X_test, y_train, y_test, scaler_X, scaler_y = prepare_data(df)
    model, predictions = train_predict_lstm(X_train, X_test, y_train, y_test, scaler_y)
    
    print("Prediction Complete.")
# Out:
# Best Feature Selection Solution: [0 1 1 0 1 0]
# Epoch 1/500
# C:\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0636 - val_loss: 0.0154
# Epoch 2/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0055 - val_loss: 0.0013
# Epoch 3/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 4/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 5/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 6/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 7/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0019 - val_loss: 8.7645e-04
# Epoch 8/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - val_loss: 9.0546e-04
# Epoch 9/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0021 - val_loss: 7.4540e-04
# Epoch 10/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 11/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017 - val_loss: 7.5076e-04
# Epoch 12/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0015 - val_loss: 9.5538e-04
# Epoch 13/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0014 - val_loss: 6.4488e-04
# Epoch 14/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0013 - val_loss: 4.3295e-04
# Epoch 15/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0015 - val_loss: 3.7519e-04
# Epoch 16/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0013 - val_loss: 3.9750e-04
# Epoch 17/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - val_loss: 3.6543e-04
# Epoch 18/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0013 - val_loss: 5.2095e-04
# Epoch 19/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0012 - val_loss: 4.7621e-04
# Epoch 20/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0012 - val_loss: 5.2072e-04
# Epoch 21/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014 - val_loss: 4.6834e-04
# Epoch 22/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0012 - val_loss: 3.6558e-04
# Epoch 23/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0012 - val_loss: 3.7983e-04
# Epoch 24/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0012 - val_loss: 3.8940e-04
# Epoch 25/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0012 - val_loss: 3.9660e-04
# Epoch 26/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0011 - val_loss: 4.1934e-04
# Epoch 27/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - val_loss: 4.2796e-04
# Epoch 28/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0010 - val_loss: 7.5244e-04
# Epoch 29/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0011 - val_loss: 4.0099e-04
# Epoch 30/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0011 - val_loss: 5.9017e-04
# Epoch 31/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.9954e-04 - val_loss: 5.6655e-04
# Epoch 32/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0012 - val_loss: 5.7041e-04
# Epoch 33/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010 - val_loss: 6.4712e-04
# Epoch 34/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010 - val_loss: 9.7126e-04
# Epoch 35/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 7.6777e-04
# Epoch 36/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - val_loss: 7.0883e-04
# Epoch 37/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.2158e-04 - val_loss: 5.9765e-04
# Epoch 38/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.3341e-04 - val_loss: 5.2776e-04
# Epoch 39/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8298e-04 - val_loss: 6.3643e-04
# Epoch 40/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0010 - val_loss: 4.8850e-04
# Epoch 41/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 5.5156e-04
# Epoch 42/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 6.4470e-04
# Epoch 43/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 5.6837e-04
# Epoch 44/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 45/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 6.0271e-04
# Epoch 46/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.8533e-04 - val_loss: 8.1491e-04
# Epoch 47/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1943e-04 - val_loss: 9.1564e-04
# Epoch 48/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9757e-04 - val_loss: 7.2951e-04
# Epoch 49/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 50/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 8.5694e-04
# Epoch 51/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5749e-04 - val_loss: 0.0013
# Epoch 52/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8623e-04 - val_loss: 9.0001e-04
# Epoch 53/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7671e-04 - val_loss: 8.2211e-04
# Epoch 54/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4992e-04 - val_loss: 8.3154e-04
# Epoch 55/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5172e-04 - val_loss: 8.6592e-04
# Epoch 56/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7223e-04 - val_loss: 6.2615e-04
# Epoch 57/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 6.4506e-04
# Epoch 58/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0194e-04 - val_loss: 7.4450e-04
# Epoch 59/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 60/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 61/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9735e-04 - val_loss: 9.4061e-04
# Epoch 62/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0070e-04 - val_loss: 6.9024e-04
# Epoch 63/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1162e-04 - val_loss: 0.0015
# Epoch 64/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9091e-04 - val_loss: 0.0012
# Epoch 65/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9065e-04 - val_loss: 8.9537e-04
# Epoch 66/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1877e-04 - val_loss: 0.0011
# Epoch 67/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9738e-04 - val_loss: 9.7519e-04
# Epoch 68/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 69/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5193e-04 - val_loss: 0.0010
# Epoch 70/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.1719e-04 - val_loss: 0.0010
# Epoch 71/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0102e-04 - val_loss: 0.0013
# Epoch 72/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8113e-04 - val_loss: 0.0013
# Epoch 73/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9737e-04 - val_loss: 0.0013
# Epoch 74/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7778e-04 - val_loss: 0.0018
# Epoch 75/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5167e-04 - val_loss: 9.8242e-04
# Epoch 76/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0168e-04 - val_loss: 9.1207e-04
# Epoch 77/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7048e-04 - val_loss: 9.9520e-04
# Epoch 78/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3976e-04 - val_loss: 0.0018
# Epoch 79/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8259e-04 - val_loss: 0.0018
# Epoch 80/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.1449e-04 - val_loss: 8.9350e-04
# Epoch 81/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4750e-04 - val_loss: 6.4556e-04
# Epoch 82/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5651e-04 - val_loss: 0.0013
# Epoch 83/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9200e-04 - val_loss: 7.6313e-04
# Epoch 84/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3957e-04 - val_loss: 0.0012
# Epoch 85/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7831e-04 - val_loss: 6.5035e-04
# Epoch 86/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1684e-04 - val_loss: 0.0010
# Epoch 87/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7990e-04 - val_loss: 6.6065e-04
# Epoch 88/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.9445e-04 - val_loss: 0.0011
# Epoch 89/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3534e-04 - val_loss: 0.0017
# Epoch 90/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5083e-04 - val_loss: 0.0013
# Epoch 91/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8684e-04 - val_loss: 0.0011
# Epoch 92/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5391e-04 - val_loss: 0.0017
# Epoch 93/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6095e-04 - val_loss: 8.6768e-04
# Epoch 94/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5795e-04 - val_loss: 7.5338e-04
# Epoch 95/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6346e-04 - val_loss: 9.0316e-04
# Epoch 96/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8138e-04 - val_loss: 8.2752e-04
# Epoch 97/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3187e-04 - val_loss: 9.4164e-04
# Epoch 98/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1694e-04 - val_loss: 8.7802e-04
# Epoch 99/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6833e-04 - val_loss: 8.3933e-04
# Epoch 100/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1258e-04 - val_loss: 7.9851e-04
# Epoch 101/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7001e-04 - val_loss: 7.7850e-04
# Epoch 102/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8498e-04 - val_loss: 7.5124e-04
# Epoch 103/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1987e-04 - val_loss: 9.5894e-04
# Epoch 104/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9291e-04 - val_loss: 0.0016
# Epoch 105/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6194e-04 - val_loss: 6.9753e-04
# Epoch 106/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6675e-04 - val_loss: 0.0021
# Epoch 107/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1746e-04 - val_loss: 9.1742e-04
# Epoch 108/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2890e-04 - val_loss: 9.8095e-04
# Epoch 109/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7045e-04 - val_loss: 9.2333e-04
# Epoch 110/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.8308e-04 - val_loss: 5.1983e-04
# Epoch 111/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8668e-04 - val_loss: 7.3098e-04
# Epoch 112/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1322e-04 - val_loss: 6.6512e-04
# Epoch 113/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2481e-04 - val_loss: 7.3675e-04
# Epoch 114/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4816e-04 - val_loss: 8.7126e-04
# Epoch 115/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9942e-04 - val_loss: 6.9600e-04
# Epoch 116/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2999e-04 - val_loss: 7.6900e-04
# Epoch 117/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8995e-04 - val_loss: 0.0013
# Epoch 118/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2806e-04 - val_loss: 8.3337e-04
# Epoch 119/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7843e-04 - val_loss: 0.0011
# Epoch 120/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3880e-04 - val_loss: 6.7210e-04
# Epoch 121/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4896e-04 - val_loss: 5.3297e-04
# Epoch 122/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5786e-04 - val_loss: 0.0011
# Epoch 123/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1431e-04 - val_loss: 0.0010
# Epoch 124/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4492e-04 - val_loss: 6.7125e-04
# Epoch 125/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5879e-04 - val_loss: 6.6080e-04
# Epoch 126/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5249e-04 - val_loss: 5.4792e-04
# Epoch 127/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4405e-04 - val_loss: 0.0014
# Epoch 128/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4480e-04 - val_loss: 0.0011
# Epoch 129/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2665e-04 - val_loss: 0.0011
# Epoch 130/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0622e-04 - val_loss: 8.5787e-04
# Epoch 131/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3517e-04 - val_loss: 6.7284e-04
# Epoch 132/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9845e-04 - val_loss: 6.2580e-04
# Epoch 133/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9839e-04 - val_loss: 4.7188e-04
# Epoch 134/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8522e-04 - val_loss: 7.2606e-04
# Epoch 135/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9181e-04 - val_loss: 6.1997e-04
# Epoch 136/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3045e-04 - val_loss: 5.7976e-04
# Epoch 137/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8826e-04 - val_loss: 4.9208e-04
# Epoch 138/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3685e-04 - val_loss: 7.8697e-04
# Epoch 139/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3116e-04 - val_loss: 5.7873e-04
# Epoch 140/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5748e-04 - val_loss: 8.8314e-04
# Epoch 141/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7600e-04 - val_loss: 0.0010
# Epoch 142/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2964e-04 - val_loss: 5.2323e-04
# Epoch 143/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9984e-04 - val_loss: 5.8158e-04
# Epoch 144/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2553e-04 - val_loss: 7.7866e-04
# Epoch 145/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9527e-04 - val_loss: 6.6649e-04
# Epoch 146/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9224e-04 - val_loss: 9.0090e-04
# Epoch 147/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.
500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5784e-04 - val_loss: 3.4377e-04
# Epoch 246/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5573e-04 - val_loss: 3.8215e-04
# Epoch 247/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0347e-04 - val_loss: 2.2618e-04
# Epoch 248/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8181e-04 - val_loss: 3.6705e-04
# Epoch 249/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9926e-04 - val_loss: 9.6474e-04
# Epoch 250/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9627e-04 - val_loss: 7.0466e-04
# Epoch 251/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5130e-04 - val_loss: 3.5936e-04
# Epoch 252/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8421e-04 - val_loss: 5.8880e-04
# Epoch 253/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3024e-04 - val_loss: 5.5554e-04
# Epoch 254/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8014e-04 - val_loss: 3.7097e-04
# Epoch 255/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9014e-04 - val_loss: 3.4670e-04
# Epoch 256/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3780e-04 - val_loss: 3.3589e-04
# Epoch 257/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4767e-04 - val_loss: 4.3015e-04
# Epoch 258/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6701e-04 - val_loss: 0.0017
# Epoch 259/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0437e-04 - val_loss: 2.5930e-04
# Epoch 260/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9758e-04 - val_loss: 3.8292e-04
# Epoch 261/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5370e-04 - val_loss: 4.9281e-04
# Epoch 262/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0652e-04 - val_loss: 2.6743e-04
# Epoch 263/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5692e-04 - val_loss: 4.7472e-04
# Epoch 264/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5728e-04 - val_loss: 2.9031e-04
# Epoch 265/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3839e-04 - val_loss: 8.8840e-04
# Epoch 266/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4430e-04 - val_loss: 6.1244e-04
# Epoch 267/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1315e-04 - val_loss: 5.2209e-04
# Epoch 268/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5988e-04 - val_loss: 8.1006e-04
# Epoch 269/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6929e-04 - val_loss: 7.6815e-04
# Epoch 270/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1161e-04 - val_loss: 6.1232e-04
# Epoch 271/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5389e-04 - val_loss: 2.0631e-04
# Epoch 272/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6697e-04 - val_loss: 7.0115e-04
# Epoch 273/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5584e-04 - val_loss: 5.7155e-04
# Epoch 274/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4927e-04 - val_loss: 2.5162e-04
# Epoch 275/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.7052e-04 - val_loss: 5.8199e-04
# Epoch 276/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8487e-04 - val_loss: 6.1925e-04
# Epoch 277/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3446e-04 - val_loss: 4.8762e-04
# Epoch 278/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3498e-04 - val_loss: 5.5964e-04
# Epoch 279/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5316e-04 - val_loss: 2.6172e-04
# Epoch 280/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9646e-04 - val_loss: 5.4663e-04
# Epoch 281/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8166e-04 - val_loss: 2.8977e-04
# Epoch 282/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9300e-04 - val_loss: 2.2277e-04
# Epoch 283/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5220e-04 - val_loss: 3.5460e-04
# Epoch 284/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1844e-04 - val_loss: 5.5235e-04
# Epoch 285/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3178e-04 - val_loss: 8.5520e-04
# Epoch 286/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4185e-04 - val_loss: 7.5121e-04
# Epoch 287/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9735e-04 - val_loss: 3.7386e-04
# Epoch 288/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1854e-04 - val_loss: 8.0634e-04
# Epoch 289/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3425e-04 - val_loss: 5.1302e-04
# Epoch 290/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3094e-04 - val_loss: 4.4653e-04
# Epoch 291/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3155e-04 - val_loss: 1.9950e-04
# Epoch 292/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4222e-04 - val_loss: 3.4913e-04
# Epoch 293/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4463e-04 - val_loss: 2.2960e-04
# Epoch 294/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3778e-04 - val_loss: 6.2412e-04
# Epoch 295/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0022e-04 - val_loss: 2.6537e-04
# Epoch 296/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3448e-04 - val_loss: 4.5362e-04
# Epoch 297/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7426e-04 - val_loss: 5.0501e-04
# Epoch 298/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1558e-04 - val_loss: 2.8629e-04
# Epoch 299/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4876e-04 - val_loss: 4.2326e-04
# Epoch 300/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9614e-04 - val_loss: 2.7161e-04
# Epoch 301/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8270e-04 - val_loss: 9.9773e-04
# Epoch 302/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1785e-04 - val_loss: 2.2158e-04
# Epoch 303/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3954e-04 - val_loss: 2.2010e-04
# Epoch 304/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2308e-04 - val_loss: 4.7317e-04
# Epoch 305/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9213e-04 - val_loss: 3.2124e-04
# Epoch 306/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9278e-04 - val_loss: 5.9017e-04
# Epoch 307/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5444e-04 - val_loss: 3.9352e-04
# Epoch 308/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2894e-04 - val_loss: 5.9179e-04
# Epoch 309/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1112e-04 - val_loss: 5.2214e-04
# Epoch 310/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2402e-04 - val_loss: 3.4856e-04
# Epoch 311/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9530e-04 - val_loss: 2.6574e-04
# Epoch 312/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.3084e-04 - val_loss: 5.7274e-04
# Epoch 313/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1963e-04 - val_loss: 3.2871e-04
# Epoch 314/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3895e-04 - val_loss: 6.8457e-04
# Epoch 315/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9132e-04 - val_loss: 8.1815e-04
# Epoch 316/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.3026e-04 - val_loss: 3.4714e-04
# Epoch 317/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.2266e-04 - val_loss: 4.6046e-04
# Epoch 318/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8612e-04 - val_loss: 2.6168e-04
# Epoch 319/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1846e-04 - val_loss: 4.3463e-04
# Epoch 320/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2108e-04 - val_loss: 6.1546e-04
# Epoch 321/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1851e-04 - val_loss: 2.5323e-04
# Epoch 322/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5426e-04 - val_loss: 6.3585e-04
# Epoch 323/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5658e-04 - val_loss: 5.0801e-04
# Epoch 324/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2492e-04 - val_loss: 2.3432e-04
# Epoch 325/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3413e-04 - val_loss: 5.3760e-04
# Epoch 326/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.5086e-04 - val_loss: 5.7269e-04
# Epoch 327/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9776e-04 - val_loss: 9.8749e-04
# Epoch 328/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.4406e-04 - val_loss: 6.7284e-04
# Epoch 329/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7981e-04 - val_loss: 5.0298e-04
# Epoch 330/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.6029e-04 - val_loss: 7.0067e-04
# Epoch 331/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2691e-04 - val_loss: 6.1456e-04
# Epoch 332/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.2856e-04 - val_loss: 3.2245e-04
# Epoch 333/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.4407e-04 - val_loss: 0.0012
# Epoch 334/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8335e-04 - val_loss: 2.3068e-04
# Epoch 335/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2811e-04 - val_loss: 2.2389e-04
# Epoch 336/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3147e-04 - val_loss: 2.9900e-04
# Epoch 337/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3477e-04 - val_loss: 6.8939e-04
# Epoch 338/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5408e-04 - val_loss: 5.9343e-04
# Epoch 339/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.4214e-04 - val_loss: 2.3303e-04
# Epoch 340/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1716e-04 - val_loss: 4.8041e-04
# Epoch 341/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0891e-04 - val_loss: 4.5017e-04
# Epoch 342/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4080e-04 - val_loss: 4.2627e-04
# Epoch 343/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8452e-04 - val_loss: 3.3113e-04
# Epoch 344/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2678e-04 - val_loss: 3.2422e-04
# Epoch 345/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9044e-04 - val_loss: 1.9688e-04
# Epoch 346/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5747e-04 - val_loss: 5.8675e-04
# Epoch 347/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5878e-04 - val_loss: 7.6525e-04
# Epoch 348/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8370e-04 - val_loss: 4.5636e-04
# Epoch 349/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9905e-04 - val_loss: 4.6253e-04
# Epoch 350/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8758e-04 - val_loss: 3.1480e-04
# Epoch 351/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5106e-04 - val_loss: 3.4700e-04
# Epoch 352/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3194e-04 - val_loss: 4.6071e-04
# Epoch 353/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1577e-04 - val_loss: 2.4497e-04
# Epoch 354/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.6921e-04 - val_loss: 3.3071e-04
# Epoch 355/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.4321e-04 - val_loss: 2.5703e-04
# Epoch 356/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5396e-04 - val_loss: 4.8988e-04
# Epoch 357/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.9580e-04 - val_loss: 5.5761e-04
# Epoch 358/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4492e-04 - val_loss: 8.8730e-04
# Epoch 359/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.6070e-04 - val_loss: 2.8435e-04
# Epoch 360/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.6103e-04 - val_loss: 2.0059e-04
# Epoch 361/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1046e-04 - val_loss: 4.5820e-04
# Epoch 362/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.4141e-04 - val_loss: 4.1044e-04
# Epoch 363/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0409e-04 - val_loss: 2.5290e-04
# Epoch 364/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1737e-04 - val_loss: 3.5159e-04
# Epoch 365/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7517e-04 - val_loss: 3.3432e-04
# Epoch 366/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2719e-04 - val_loss: 5.3246e-04
# Epoch 367/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0492e-04 - val_loss: 3.5638e-04
# Epoch 368/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1618e-04 - val_loss: 4.7137e-04
# Epoch 369/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7263e-04 - val_loss: 2.8233e-04
# Epoch 370/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1964e-04 - val_loss: 0.0010
# Epoch 371/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1461e-04 - val_loss: 7.9096e-04
# Epoch 372/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2481e-04 - val_loss: 2.5530e-04
# Epoch 373/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1474e-04 - val_loss: 4.3642e-04
# Epoch 374/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0594e-04 - val_loss: 1.5830e-04
# Epoch 375/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5405e-04 - val_loss: 4.5380e-04
# Epoch 376/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7468e-04 - val_loss: 8.6630e-04
# Epoch 377/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1542e-04 - val_loss: 6.9588e-04
# Epoch 378/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9653e-04 - val_loss: 7.5500e-04
# Epoch 379/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4688e-04 - val_loss: 3.3670e-04
# Epoch 380/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7483e-04 - val_loss: 3.4236e-04
# Epoch 381/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.6187e-04 - val_loss: 4.7707e-04
# Epoch 382/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3535e-04 - val_loss: 7.3945e-04
# Epoch 383/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0563e-04 - val_loss: 4.5890e-04
# Epoch 384/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3405e-04 - val_loss: 4.1243e-04
# Epoch 385/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 2.1664e-04 - val_loss: 3.6084e-04
# Epoch 386/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - loss: 2.0958e-04 - val_loss: 4.3604e-04
# Epoch 387/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 2.0912e-04 - val_loss: 5.9977e-04
# Epoch 388/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.5177e-04 - val_loss: 0.0020
# Epoch 389/500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - loss: 2.3300e-04 - val_loss: 4.3613e-04
# Epoch 390/500
# 13/50 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 2.0129e-04
